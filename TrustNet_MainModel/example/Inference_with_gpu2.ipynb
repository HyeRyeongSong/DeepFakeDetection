# %%
# !python predict_folder-gpu2.py --test-dir "../dfdc_train_all/dfdc_test/dfdc_train_part_45" --output "45.csv" --models b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Out:
# loading state dict weights/b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Predicting 2346 videos
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_45/aaeflzzhvy.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_45/aaeucwtkdx.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_45/abwlafapkf.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_45/acjwdlpzob.mp4
# ...

# %%
# !python predict_folder-gpu2.py --test-dir "../dfdc_train_all/dfdc_test/dfdc_train_part_46" --output "46.csv" --models b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Out:
# loading state dict weights/b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Predicting 2202 videos
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_46/aagsmskgyw.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_46/abfwqxqcim.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_46/aazkzzkbns.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_46/abacmovtxb.mp4
# ...

# %%
# !python predict_folder-gpu2.py --test-dir "../dfdc_train_all/dfdc_test/dfdc_train_part_47" --output "47.csv" --models b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Out:
# loading state dict weights/b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Predicting 2406 videos
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_47/achejkrwas.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_47/aciukwyoli.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_47/aeviyhvand.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_47/aflspexpuy.mp4
# ...

# %%
# !python predict_folder-gpu2.py --test-dir "../dfdc_train_all/dfdc_test/dfdc_train_part_48" --output "48.csv" --models b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Out:
# loading state dict weights/b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Predicting 2463 videos
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_48/abbhzhtjru.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_48/aafuphyhpt.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_48/abzkaeazro.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_48/acfaxepklq.mp4
# ...

# %%
# !python predict_folder-gpu2.py --test-dir "../dfdc_train_all/dfdc_test/dfdc_train_part_49" --output "49.csv" --models b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22 b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37 b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29 b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Out:
# loading state dict weights/b7_111_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_555_DeepFakeClassifier_tf_efficientnet_b7_ns_0_24
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_22
# loading state dict weights/b7_777_DeepFakeClassifier_tf_efficientnet_b7_ns_0_37
# loading state dict weights/b7_888_DeepFakeClassifier_tf_efficientnet_b7_ns_0_36
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_29
# loading state dict weights/b7_999_DeepFakeClassifier_tf_efficientnet_b7_ns_0_34
# Predicting 3134 videos
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_49/abmdetdeok.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_49/abdgairkrk.mp4
# Error grabbing frame 283 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_49/abgrdkbhch.mp4
# Error grabbing frame 284 from movie ../dfdc_train_all/dfdc_test/dfdc_train_part_49/accfrqkrni.mp4
# ...
